# %% [markdown]
# # Figure 7 — JVP Phase Transition
#
# Reproduces **Figure 7** from
# [Ghosts of Softmax](https://arxiv.org/abs/2503.XXXXX).
#
# Phase transition measured via exact JVP radius.

# %%
import os, subprocess, sys

if 'google.colab' in sys.modules:
    subprocess.run(['git', 'clone', 'https://github.com/piyush314/ghosts-of-softmax.git'], check=True)
    os.chdir('ghosts-of-softmax')
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-e', '.'], check=True)
else:
    os.chdir(os.path.join(os.path.dirname('__file__'), '..'))

# %%
subprocess.run(
    [sys.executable, 'experiments/phasetransition/run.py', '--smoke'],
    check=True,
)
subprocess.run(
    [sys.executable, 'experiments/phasetransition/plotjvp.py'],
    check=True,
)

# %%
from IPython.display import Image
Image('experiments/phasetransition/results/phase-jvp.png')
